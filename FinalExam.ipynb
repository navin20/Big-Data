# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/WHO-COVID-19-global-data.csv

# %% [markdown]
# # Task 1

# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/WHO-COVID-19-global-data.csv")

# %%
df
# Out:
#               day Country Country Name Region  Deaths  Cumulative Deaths  \
# 0      2020-02-24      AF  Afghanistan   EMRO       0                  0
# 1      2020-02-25      AF  Afghanistan   EMRO       0                  0
# 2      2020-02-26      AF  Afghanistan   EMRO       0                  0
# 3      2020-02-27      AF  Afghanistan   EMRO       0                  0
# 4      2020-02-28      AF  Afghanistan   EMRO       0                  0
# ...           ...     ...          ...    ...     ...                ...
# 11167  2020-04-22      ZW     Zimbabwe   AFRO       0                  3
# 11168  2020-04-23      ZW     Zimbabwe   AFRO       1                  4
# 11169  2020-04-24      ZW     Zimbabwe   AFRO       0                  4
# 11170  2020-04-25      ZW     Zimbabwe   AFRO       0                  4
# 11171  2020-04-26      ZW     Zimbabwe   AFRO       0                  4
#
#        Confirmed  Cumulative Confirmed
# 0              1                     1
# ...

# %% [markdown]
# # this data is downloaded from this link  https://covid19.who.int/
# # and is downloaded to the local computer than uploaded to the kaggle datasource
# ## this data is the data of the corona virus that has been occuring in few months from now which is a global issue.
# ## the data basically consists of data of countries that have confirmed cases of the corona virus. it basically has
# ## some of the numerical and string columns.

# %%
df.shape
# Out:
# (11172, 8)

# %%
landf = df

# %% [markdown]
# ## here basically shows that there is 11172 rows in the dataset and 8 columns

# %%
df['day']
# Out:
# 0        2020-02-24
# 1        2020-02-25
# 2        2020-02-26
# 3        2020-02-27
# 4        2020-02-28
#             ...
# 11167    2020-04-22
# 11168    2020-04-23
# 11169    2020-04-24
# 11170    2020-04-25
# 11171    2020-04-26
# Name: day, Length: 11172, dtype: object

# %% [markdown]
# # the date range coverage is from 2020-02-24 to 2020-04-26 according to the dataset

# %% [markdown]
# #  Task 2

# %%
abcd = df.groupby('Country')['Country'].count()

# %%
abcd
# Out:
# Country
# AD    56
# AE    89
# AF    63
# AG    45
# AI    32
#       ..
# YE    17
# YT    44
# ZA    53
# ZM    40
# ZW    38
# Name: Country, Length: 211, dtype: int64

# %% [markdown]
# ## There are 211 countries in the dataset

# %%
df.count()
# Out:
# day                     11172
# Country                 11046
# Country Name            11172
# Region                  11090
# Deaths                  11172
# Cumulative Deaths       11172
# Confirmed               11172
# Cumulative Confirmed    11172
# dtype: int64

# %%
y = df['day'].min()

# %%
y
# Out:
# '2020-01-08'

# %% [markdown]
# # first date of corona confirmed case

# %%
h = df.groupby(['day'])['Country Name'].min()

# %%
h[1]
# Out:
# 'Thailand'

# %% [markdown]
# ## Thailand is basically the first country with the confirmed case

# %% [markdown]
# Thailand is the confirm first case

# %%
from matplotlib import pyplot as plt

# %%
# rf = df.head()

# %%
options = ['Thailand','Afghanistan']
stu = ['TH','CH','AF']

# %%
# rf =rf[(rf['Country Name']=='Thailand') |(rf['Country Name']=='China')  |(rf['Country Name']=='Afghanistan')]

# %%
# rf[rf['Country Name'].isin(stk_list)]
# rf[rf['Country']].isin(s

rf = df.head(11172)

# %%
new = rf["Country Name"].isin(["Thailand","China","Afghanistan"])

# %%
rf[new]
# Out:
#               day Country Country Name Region  Deaths  Cumulative Deaths  \
# 0      2020-02-24      AF  Afghanistan   EMRO       0                  0
# 1      2020-02-25      AF  Afghanistan   EMRO       0                  0
# 2      2020-02-26      AF  Afghanistan   EMRO       0                  0
# 3      2020-02-27      AF  Afghanistan   EMRO       0                  0
# 4      2020-02-28      AF  Afghanistan   EMRO       0                  0
# ...           ...     ...          ...    ...     ...                ...
# 10126  2020-04-22      TH     Thailand  SEARO       1                 49
# 10127  2020-04-23      TH     Thailand  SEARO       1                 50
# 10128  2020-04-24      TH     Thailand  SEARO       0                 50
# 10129  2020-04-25      TH     Thailand  SEARO       1                 51
# 10130  2020-04-26      TH     Thailand  SEARO       0                 51
#
#        Confirmed  Cumulative Confirmed
# 0              1                     1
# ...

# %%
xpl= rf[new].values.tolist()
ypl = rf['Cumulative Confirmed'].head(20).values.tolist()

# %%
# Out:
# Text(0, 0.5, 'Country')

# %%
xpl1 = rf["Country Name"].isin(["Thailand"])

# %%
thailand = rf[xpl1].values.tolist()

# %%
type(ypl)
# Out:
# list

# %%
ypl
xpl1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11167    False
# 11168    False
# 11169    False
# 11170    False
# 11171    False
# Name: Country Name, Length: 11172, dtype: bool

# %%
plt.xlabel("Country")
plt.ylabel("Cumulative Confirm")
plt.plot(thailand,ypl)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-352-9db2fb46dddf> in <module>
#       1 plt.xlabel("Country")
#       2 plt.ylabel("Cumulative Confirm")
# ----> 3 plt.plot(thailand,ypl)
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# ...

# %%
rf[new].head(20)
# Out:
# Empty DataFrame
# Columns: [day, Country, Country Name, Region, Deaths, Cumulative Deaths, Confirmed, Cumulative Confirmed]
# Index: []

# %%
rf.head(20)
# Out:
# Empty DataFrame
# Columns: [day, Country, Country Name, Region, Deaths, Cumulative Deaths, Confirmed, Cumulative Confirmed]
# Index: []

# %%
result['Country Name']
# Out:
# Series([], Name: Country Name, dtype: bool)

# %%
df['Country']
# Out:
# 0        AF
# 1        AF
# 2        AF
# 3        AF
# 4        AF
#          ..
# 11167    ZW
# 11168    ZW
# 11169    ZW
# 11170    ZW
# 11171    ZW
# Name: Country, Length: 11172, dtype: object

# %%
# Out:
# array([False])

# %%
plt.plot(x,y)

# %% [markdown]
# #  task 2 question 4:Which Country has the most confirmed Deaths?

# %%
hi = landf.groupby(['Deaths'])['Country Name'].max()

# %%
hi[0]
# Out:
# 'occupied Palestinian territory, including east Jerusalem'

# %% [markdown]
# ## the most death is at occupied Palestinian territory

# %%
orf = df

# %%
orf
# Out:
#               day Country Country Name Region  Deaths  Cumulative Deaths  \
# 0      2020-02-24      AF  Afghanistan   EMRO       0                  0
# 1      2020-02-25      AF  Afghanistan   EMRO       0                  0
# 2      2020-02-26      AF  Afghanistan   EMRO       0                  0
# 3      2020-02-27      AF  Afghanistan   EMRO       0                  0
# 4      2020-02-28      AF  Afghanistan   EMRO       0                  0
# ...           ...     ...          ...    ...     ...                ...
# 11167  2020-04-22      ZW     Zimbabwe   AFRO       0                  3
# 11168  2020-04-23      ZW     Zimbabwe   AFRO       1                  4
# 11169  2020-04-24      ZW     Zimbabwe   AFRO       0                  4
# 11170  2020-04-25      ZW     Zimbabwe   AFRO       0                  4
# 11171  2020-04-26      ZW     Zimbabwe   AFRO       0                  4
#
#        Confirmed  Cumulative Confirmed
# 0              1                     1
# ...

# %% [markdown]
# #  Task 3

# %% [markdown]
# ## Since my accuracy below is not good  i will explain how to create machine learning model for predicting confirmed cases
# ### 1)first of all we need we nee d to prepare data and process data to make it suitable to use .
#  ### the country name column will be from  categorical numbers to numerical values using label encoder and
#  ### the confirmed columns will be normalized using min max scaler to values that can be predictable since the column have a continuous values.
#  ### 2)the data will be split to train and  test set after preparing the data with test size limit set  about 30%.
# ### 3) i choose the algorithm random forest regressor and ita random forest parameter its parameters will also be set to make it suitable.
# ### 4) after defining the algorithms we will go train the model  by fitting the the input col and the label columns into the random forest regressor model.
# ### 5) after we finish training we will use the data and predict the confirmed case of target country  where we can show and see whether the predicted matches the original or not and check the mean square error and the accuracy when using with the test set.

# %%
features= ['Country Name']
X = orf[features]
y = orf[['Confirmed']].values.astype(float)

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
y_scaled = min_max_scaler.fit_transform(y)

# %%
orf['Confirmed'] = y_scaled

# %%
orf
# Out:
#               day Country Country Name Region  Deaths  Cumulative Deaths  \
# 0      2020-02-24      AF  Afghanistan   EMRO       0                  0
# 1      2020-02-25      AF  Afghanistan   EMRO       0                  0
# 2      2020-02-26      AF  Afghanistan   EMRO       0                  0
# 3      2020-02-27      AF  Afghanistan   EMRO       0                  0
# 4      2020-02-28      AF  Afghanistan   EMRO       0                  0
# ...           ...     ...          ...    ...     ...                ...
# 11167  2020-04-22      ZW     Zimbabwe   AFRO       0                  3
# 11168  2020-04-23      ZW     Zimbabwe   AFRO       1                  4
# 11169  2020-04-24      ZW     Zimbabwe   AFRO       0                  4
# 11170  2020-04-25      ZW     Zimbabwe   AFRO       0                  4
# 11171  2020-04-26      ZW     Zimbabwe   AFRO       0                  4
#
#        Confirmed  Cumulative Confirmed
# 0       0.000026                     1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
yon = orf['Confirmed']

# %%
yon
# Out:
# 0        0.000026
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#            ...
# 11167    0.000078
# 11168    0.000000
# 11169    0.000000
# 11170    0.000026
# 11171    0.000052
# Name: Confirmed, Length: 11172, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
orf['Country Name'] = labelencoder.fit_transform(orf['Country Name'])

# %%
yuii =orf.Confirmed.values.reshape(-1, 1)
ouy = orf['Country Name'].values.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(ouy, yuii, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
randomForest = RandomForestRegressor(n_estimators=100)

# %%
randomForest.fit(x_train,y_train)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred = randomForest.predict(x_test)

# %%
errors = abs(y_pred - y_test)

# %%
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 0.01 degrees.

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.36315460033081925

# %%
# comparing 3000 datas
# Out:
#   File "<ipython-input-240-820e697c9ca2>", line 1
#     comparing 3000 datas
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# # #comparing 3000 datas

# %%
# mape = 100 * (errors / y_test)
# # Calculate and display accuracy
# accuracy = 100 - np.mean(mape)
# print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: -inf %.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
 from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 0.0010362078982118286
